# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Salaries.csv')
df
# Out:
# C:\Users\abhishek30april\ANACONDA\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3,4,5,6,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY        167411
# 1                      CAPTAIN III (POLICE DEPARTMENT)        155966
# 2                      CAPTAIN III (POLICE DEPARTMENT)        212739
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
df.describe()
# Out:
#                   Id       TotalPay  TotalPayBenefits           Year  Notes
# count  148654.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    74327.500000   74768.321972      93692.554811    2012.522643    NaN
# std     42912.857795   50517.005274      62793.533483       1.117538    NaN
# min         1.000000    -618.130000       -618.130000    2011.000000    NaN
# 25%     37164.250000   36168.995000      44065.650000    2012.000000    NaN
# 50%     74327.500000   71426.610000      92404.090000    2013.000000    NaN
# 75%    111490.750000  105839.135000     132876.450000    2014.000000    NaN
# max    148654.000000  567595.430000     567595.430000    2014.000000    NaN

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.replace('Not Provided',np.nan,inplace=True)

# %%
df.replace('Not provided',np.nan,inplace=True)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651                NaN
# 148651  148652                NaN
# 148652  148653                NaN
# 148653  148654          Joe Lopez
#
#                                               JobTitle BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411           0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966      245132
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739      106088
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916     56120.7
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134402        9737
# ...                                                ...     ...         ...
# ...

# %%
sns.heatmap(df.isnull())

# %%
df['Benefits'].value_counts()
# Out:
# 0.0         1053
# 0.00         681
# 7959.18      348
# 4659.36      107
# 25699.2       83
#             ...
# 39667.3        1
# 48.97          1
# 34420.13       1
# 35022.93       1
# 185.69         1
# Name: Benefits, Length: 99634, dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy='mean')
df['Benefits'] = si.fit_transform(df['Benefits'].values.reshape(-1,1))

# %%
sns.heatmap(df.isnull())

# %%
df['Status'].value_counts()
# Out:
# FT    22334
# PT    15785
# Name: Status, dtype: int64

# %%
df['Status'].replace(np.nan,0,inplace=True)

# %%
sns.heatmap(df.isnull())

# %%
df.drop('Notes',axis=1,inplace=True)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651                NaN
# 148651  148652                NaN
# 148652  148653                NaN
# 148653  148654          Joe Lopez
#
#                                               JobTitle BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411           0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966      245132
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739      106088
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916     56120.7
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134402        9737
# ...                                                ...     ...         ...
# ...

# %%
df.dropna(axis=0,inplace=True)

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   Carolyn A Wilson
# 148647  148648     Joann Anderson
# 148648  148649        Leon Walker
# 148649  148650      Roy I Tillery
# 148653  148654          Joe Lopez
#
#                                               JobTitle BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411           0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966      245132
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739      106088
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916     56120.7
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134402        9737
# ...                                                ...     ...         ...
# ...

# %%
df.describe()
# Out:
#                   Id       Benefits       TotalPay  TotalPayBenefits  \
# count  148043.000000  148043.000000  148043.000000     148043.000000
# mean    74193.290902   25088.257642   75057.555265      94037.888854
# std     42948.417213   13364.334588   50410.007571      62683.725358
# min         1.000000     -13.800000    -618.130000       -618.130000
# 25%     37012.500000   22746.870000   36956.850000      45074.275000
# 50%     74024.000000   25007.893151   71644.330000      92675.510000
# 75%    111639.500000   33507.225000  106028.000000     133085.380000
# max    148654.000000   96570.660000  567595.430000     567595.430000
#
#                 Year
# count  148043.000000
# mean     2012.520666
# std         1.119390
# min      2011.000000
# 25%      2012.000000
# 50%      2013.000000
# 75%      2014.000000
# max      2014.000000

# %%
df['BasePay'] = df['BasePay'].astype('float')

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148645  148646   Carolyn A Wilson
# 148647  148648     Joann Anderson
# 148648  148649        Leon Walker
# 148649  148650      Roy I Tillery
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18           0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02      245132
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13      106088
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.7
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60        9737
# ...                                                ...        ...         ...
# ...

# %%
df['OtherPay'] = df['OtherPay'].astype('float')

# %%
df['OvertimePay'] = df['OvertimePay'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148043 entries, 0 to 148653
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148043 non-null  int64
#  1   EmployeeName      148043 non-null  object
#  2   JobTitle          148043 non-null  object
#  3   BasePay           148043 non-null  float64
#  4   OvertimePay       148043 non-null  object
#  5   OtherPay          148043 non-null  object
#  6   Benefits          148043 non-null  float64
#  7   TotalPay          148043 non-null  float64
#  8   TotalPayBenefits  148043 non-null  float64
#  9   Year              148043 non-null  int64
#  10  Agency            148043 non-null  object
#  11  Status            148043 non-null  object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 14.7+ MB

# %%
df.describe()
# Out:
#                   Id        BasePay       Benefits       TotalPay  \
# count  148043.000000  148043.000000  148043.000000  148043.000000
# mean    74193.290902   66325.398119   25088.257642   75057.555265
# std     42948.417213   42764.898947   13364.334588   50410.007571
# min         1.000000    -166.010000     -13.800000    -618.130000
# 25%     37012.500000   33587.350000   22746.870000   36956.850000
# 50%     74024.000000   65007.450000   25007.893151   71644.330000
# 75%    111639.500000   94691.050000   33507.225000  106028.000000
# max    148654.000000  319275.010000   96570.660000  567595.430000
#
#        TotalPayBenefits           Year
# count     148043.000000  148043.000000
# mean       94037.888854    2012.520666
# std        62683.725358       1.119390
# min         -618.130000    2011.000000
# 25%        45074.275000    2012.000000
# 50%        92675.510000    2013.000000
# 75%       133085.380000    2014.000000
# max       567595.430000    2014.000000

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Agency', 'Status'],
#       dtype='object')

# %%
df.drop(['Id','EmployeeName','JobTitle','Year','Agency','Status'],axis=1,inplace=True)

# %%
df
# Out:
#           BasePay OvertimePay OtherPay      Benefits   TotalPay  \
# 0       167411.18           0   400184  25007.893151  567595.43
# 1       155966.02      245132   137811  25007.893151  538909.28
# 2       212739.13      106088  16452.6  25007.893151  335279.91
# 3        77916.00     56120.7   198307  25007.893151  332343.61
# 4       134401.60        9737   182235  25007.893151  326373.19
# ...           ...         ...      ...           ...        ...
# 148645       0.00        0.00     0.00      0.000000       0.00
# 148647       0.00        0.00     0.00      0.000000       0.00
# 148648       0.00        0.00     0.00      0.000000       0.00
# 148649       0.00        0.00     0.00      0.000000       0.00
# 148653       0.00        0.00  -618.13      0.000000    -618.13
#
#         TotalPayBenefits
# 0              567595.43
# 1              538909.28
# 2              335279.91
# 3              332343.61
# 4              326373.19
# ...                  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148043 entries, 0 to 148653
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   BasePay           148043 non-null  float64
#  1   OvertimePay       148043 non-null  float64
#  2   OtherPay          148043 non-null  float64
#  3   Benefits          148043 non-null  float64
#  4   TotalPay          148043 non-null  float64
#  5   TotalPayBenefits  148043 non-null  float64
# dtypes: float64(6)
# memory usage: 7.9 MB

# %%
df1 = df[df['TotalPay']>0]

# %%
df1
# Out:
#           BasePay  OvertimePay   OtherPay      Benefits   TotalPay  \
# 0       167411.18         0.00  400184.25  25007.893151  567595.43
# 1       155966.02    245131.88  137811.38  25007.893151  538909.28
# 2       212739.13    106088.18   16452.60  25007.893151  335279.91
# 3        77916.00     56120.71  198306.90  25007.893151  332343.61
# 4       134401.60      9737.00  182234.59  25007.893151  326373.19
# ...           ...          ...        ...           ...        ...
# 148621       0.00         0.00      15.35      0.000000      15.35
# 148622       0.00         0.00      13.77      0.000000      13.77
# 148623       0.00         0.00      13.35      0.130000      13.35
# 148624       0.00         0.00      12.89      0.000000      12.89
# 148625       0.00         0.00       6.00      1.240000       6.00
#
#         TotalPayBenefits
# 0              567595.43
# 1              538909.28
# 2              335279.91
# 3              332343.61
# 4              326373.19
# ...

# %%
sns.pairplot(df1)

# %%
sns.distplot(df1['TotalPayBenefits'])

# %%
sns.heatmap(df1.corr())

# %%
X = df1.drop('TotalPayBenefits',axis=1)
y = df1['TotalPayBenefits']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
lrpred = lr.predict(X_test)
lrpred
# Out:
# array([ 82717.71570269, 177030.21198345,  76893.81676611, ...,
#        241958.7396453 , 160232.93950922, 156003.52714202])

# %%
lr.coef_
# Out:
# array([0.26765348, 0.26635624, 0.22189707, 0.93908024, 0.75590678])

# %%
lr.intercept_
# Out:
# -6169.097267586985

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mean_absolute_error(y_test,lrpred)
# Out:
# 9202.230528969341

# %%
mean_squared_error(y_test,lrpred)
# Out:
# 115118765.57254532

# %%
np.sqrt(mean_squared_error(y_test,lrpred))
# Out:
# 10729.341339175733

# %%
r2_score(y_test,lrpred)
# Out:
# 0.9707606157080665

# %%
plt.scatter(y_test,lrpred)

# %%
sns.distplot(y_test-lrpred)

# %%
from scipy.stats import zscore
z=np.abs(zscore(df1))
z
# Out:
# array([[2.36382211e+00, 4.43482242e-01, 4.94362138e+01, 6.86380703e-03,
#         9.77299411e+00, 7.55622255e+00],
#        [2.09609343e+00, 2.09179772e+01, 1.67261985e+01, 6.86380703e-03,
#         9.20375502e+00, 7.09845183e+00],
#        [3.42414737e+00, 8.80133060e+00, 1.59640419e+00, 6.86380703e-03,
#         5.16299677e+00, 3.84895467e+00],
#        ...,
#        [1.55231137e+00, 4.43482242e-01, 4.53076456e-01, 1.87897023e+00,
#         1.48992916e+00, 1.50119356e+00],
#        [1.55231137e+00, 4.43482242e-01, 4.53133804e-01, 1.87897997e+00,
#         1.48993829e+00, 1.50120297e+00],
#        [1.55231137e+00, 4.43482242e-01, 4.53992780e-01, 1.87888714e+00,
#         1.49007501e+00, 1.50129314e+00]])

# %%
threshold=3
np.where(z>3)
# Out:
# (array([     0,      0,      0, ..., 139336, 139393, 139871], dtype=int64),
#  array([2, 4, 5, ..., 2, 2, 2], dtype=int64))

# %%
df2=df1[(z<3).all(axis=1)]
df2
# Out:
#           BasePay  OvertimePay  OtherPay      Benefits   TotalPay  \
# 100     168692.65     33656.87  21502.83  25007.893151  223852.35
# 125     185369.68     27321.83   4651.44  25007.893151  217342.95
# 126     192170.93     11260.27  13712.80  25007.893151  217144.00
# 127     168692.63     22432.91  25855.73  25007.893151  216981.27
# 134     166203.84     28448.60  20744.06  25007.893151  215396.50
# ...           ...          ...       ...           ...        ...
# 148621       0.00         0.00     15.35      0.000000      15.35
# 148622       0.00         0.00     13.77      0.000000      13.77
# 148623       0.00         0.00     13.35      0.130000      13.35
# 148624       0.00         0.00     12.89      0.000000      12.89
# 148625       0.00         0.00      6.00      1.240000       6.00
#
#         TotalPayBenefits
# 100            223852.35
# 125            217342.95
# 126            217144.00
# 127            216981.27
# 134            215396.50
# ...

# %%
X = df2.drop('TotalPayBenefits',axis=1)
y = df2['TotalPayBenefits']

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
lrpred = lr.predict(X_test)
lrpred
# Out:
# array([ 82717.71570269, 177030.21198345,  76893.81676611, ...,
#        241958.7396453 , 160232.93950922, 156003.52714202])

# %%
lr.coef_
# Out:
# array([0.26765348, 0.26635624, 0.22189707, 0.93908024, 0.75590678])

# %%
lr.intercept_
# Out:
# -6169.097267586985

# %%
mean_absolute_error(y_test,lrpred)
# Out:
# 9202.230528969341

# %%
mean_squared_error(y_test,lrpred)
# Out:
# 115118765.57254532

# %%
np.sqrt(mean_squared_error(y_test,lrpred))
# Out:
# 10729.341339175733

# %%
r2_score(y_test,lrpred)
# Out:
# 0.9707606157080665
